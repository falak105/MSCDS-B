# %%
class student:
    def __init__(self):
        self.details=[]
    def add_student(self,name,dep,regno,email,eng,maths,computer,economics):
        det={
            'name':name,
            'dep':dep,
            'regno':regno,
            'email':email,
            'eng':eng,
            'maths':maths,
            'computer':computer,
            'economics':economics
        }
        self.details.append(det)
        print(f"{det}Added the Detais")
    def list_students(self):
        if self.details:
         print(self.details)
        else:
          print("Details not added")
    def search_student(self,regno):
        for regno in self.details:
            if regno == regno:
                print(regno)
                print("Student exist")
            else:
                print("Student dose not exist")
    def remove_student(self,regno):
        for regno in self.details:
            if regno==regno:
                self.details.remove(regno)
                print(self.details)
                print("Student details removed")
            else:
                print("Student dose not exist")

# %%
sd=student()
while(True):
    print("Chioces")
    print("1.Add Student")
    print("2.List all the Student")
    print("3.Search the student")
    print("4.Remove the Student")
    print("5.Quit")

    chioce=input("Enter your chioce")
    if chioce=="1":
        name=input("Enter the name")
        dep=input("Enter the department")
        regno=input("Enter the register number")
        email=input("Enter the email id")
        eng=input("enter the marks for English")
        maths=input("enter the marks for Maths")
        computer=input("enter the marks for Computer")
        economics=input("enter the marksfor Economics")
        st=sd.add_student(name,dep,regno,email,eng,maths,computer,economics)
        print(st)
        print("details Added")
    if chioce=="2":
        st=sd.list_students()
        print(st)
        print("List of the student")
    elif  chioce=="3":
        st=sd.search_student(regno)
        regno=input("Enter the register number of the student")
        print(st)
    elif chioce=="4":
        st=sd.remove_student(regno)
        regno=input("Enter the register number of the student")
        print(st)
    elif  chioce =="5":
        break
    else:
        print("invalid chioce ")
# Out:
# Chioces
# 1.Add Student
# 2.List all the Student
# 3.Search the student
# 4.Remove the Student
# 5.Quit
# {'name': 'Falak', 'dep': 'Msds', 'regno': '23122106', 'email': 'ansari@gmail.com', 'eng': '33', 'maths': '34', 'computer': '44', 'economics': '43'}Added the Detais
# None
# details Added
# invalid chioce
# Chioces
# 1.Add Student
# 2.List all the Student
# 3.Search the student
# 4.Remove the Student
# 5.Quit
# [{'name': 'Falak', 'dep': 'Msds', 'regno': '23122106', 'email': 'ansari@gmail.com', 'eng': '33', 'maths': '34', 'computer': '44', 'economics': '43'}]
# None
# List of the student
# Chioces
# 1.Add Student
# 2.List all the Student
# 3.Search the student
# 4.Remove the Student
# 5.Quit
# {'name': 'Falak', 'dep': 'Msds', 'regno': '23122106', 'email': 'ansari@gmail.com', 'eng': '33', 'maths': '34', 'computer': '44', 'economics': '43'}
# Student exist
# None
# Chioces
# 1.Add Student
# 2.List all the Student
# 3.Search the student
# 4.Remove the Student
# 5.Quit
# []
# Student details removed
# None
# Chioces
# 1.Add Student
# 2.List all the Student
# 3.Search the student
# 4.Remove the Student
# 5.Quit
